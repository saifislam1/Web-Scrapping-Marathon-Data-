# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
from datetime import datetime

# %%
from lxml import html
import requests

# %%
pages_2016 = 154
pages_2017 = 147
pages_2018 = 85
pages_2019 = 113
pgs_half_2016 = 898
pgs_half_2017 = 892
pgs_half_2018 = 598
pgs_half_2019 = 690

# %%
urlbase_2019 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2019-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_2018 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2018-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_2017 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2017-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_2016 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2016-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_half_2019 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2019-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_half_2018 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2018-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_half_2017 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2017-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='
urlbase_half_2016 = 'https://www.runrocknroll.com/Events/Nashville/The-Races/Half-Marathon/2016-Results?gender=&agegroup=&bib=&firstname=&lastname=&page='

# %%
base=urlbase_2019
page = 99
url=base +str(99)

# %%
result=requests.post(url)
result.content
soup = BS(result.text,'lxml')

# %%
tables=soup.find_all('table',attrs = {'class': "table table-responsive table-bordered"})

# %%
results_list=pd.read_html(str(tables[0]))

# %%
results_list
# Out:
# [    Overall    Bib                       Name      Time
#  0     99999  32320            Melinda Bennett  00:00:00
#  1     99999  31056                Jane Karnap  00:00:00
#  2     99999  31528                Nora Snoddy  00:00:00
#  3     99999  31038                  Emma Hogg  00:00:00
#  4     99999  32696            Kristina Warren  00:00:00
#  5     99999  32319                Nikkia Bell  00:00:00
#  6     99999  30291               Davey Dobson  00:00:00
#  7     99999  32491                 Jan Melton  00:00:00
#  8     99999  33001            Tiffany Sommers  00:00:00
#  9     99999  30930               Casey Cooney  00:00:00
#  10    99999  32343               Dave Chesson  00:00:00
#  11    99999  32678                Chad Taylor  00:00:00
#  12    99999  32912  Courtney J Gordon-Tennant  00:00:00
#  13    99999  30162                 Dustin Lee  00:00:00
#  14    99999  31781             Sheila Fischer  00:00:00
# ...

# %%
df_1 = results_list[0]

# %%
page=0
full_2016 = pd.DataFrame()
for page in range(154):
  base1 = urlbase_2016
  page = page +1
  url1 = base1 + str(page)
  result1 = requests.post(url1)
  soup1 = BS(result1.text, 'lxml')
  tables1 = soup1.find_all("table", attrs = {"class":"table table-responsive table-bordered"})
  results_list1 = pd.read_html(str(tables1[0]))
  full_2016 = full_2016.append(results_list1)

# %%
full_2016['Year'] = 2016

# %%
full_2016['Time'] = pd.to_timedelta(full_2016['Time'])

# %%
full_2016_topten = full_2016.head(10)

# %%
full_2016_topten
# Out:
#    Overall   Bib               Name     Time  Year
# 0        1     1     Scott Wietecha 02:25:42  2016
# 1        2     3      Brian Shelton 02:34:43  2016
# 2        3  1047  Christopher Capps 02:38:43  2016
# 3        4  1052       Jason Grimes 02:45:06  2016
# 4        5  1046        David Adams 02:47:28  2016
# 5        6  1049    Matthew Meinema 02:47:36  2016
# 6        7  1044        Seth Carley 02:48:22  2016
# 7        8  1092         Ben Becker 02:52:19  2016
# 8        9  1057     Jonathan Mason 02:53:38  2016
# 9       10  1058         Matt Treat 02:53:48  2016

# %%
full_2016_topten.describe()
# Out:
#         Overall          Bib                    Time    Year
# count  10.00000    10.000000                      10    10.0
# mean    5.50000   844.900000  0 days 02:44:44.500000  2016.0
# std     3.02765   444.458834  0 days 00:09:06.533367     0.0
# min     1.00000     1.000000         0 days 02:25:42  2016.0
# 25%     3.25000  1044.500000  0 days 02:40:18.750000  2016.0
# 50%     5.50000  1048.000000         0 days 02:47:32  2016.0
# 75%     7.75000  1055.750000  0 days 02:51:19.750000  2016.0
# max    10.00000  1092.000000         0 days 02:53:48  2016.0

# %%
full_2016_topten

# %%
page=0
full_2017 = pd.DataFrame()
for page in range(147):
  base2 = urlbase_2017
  page = page +1
  url2 = base2 + str(page)
  result2 = requests.post(url2)
  soup2 = BS(result2.text, 'lxml')
  tables2 = soup2.find_all("table", attrs = {"class":"table table-responsive table-bordered"})
  results_list2 = pd.read_html(str(tables2[0]))
  full_2017 = full_2017.append(results_list2)

# %%
full_2017['Year'] = 2017

# %%
full_2017_topten = full_2017.head(10)

# %%
full_2017_topten
# Out:
#    Overall   Bib               Name      Time  Year
# 0        1     1     Scott Wietecha  02:40:25  2017
# 1        2  1145       Ryan Regnier  02:56:28  2017
# 2        3  1147     Daniel Everett  03:00:55  2017
# 3        4  1029      Khris Vickroy  03:04:47  2017
# 4        5  1119     Marcus Dilallo  03:04:53  2017
# 5        6  1135        Edgar Garza  03:06:20  2017
# 6        7  1129          Brad Sawa  03:06:47  2017
# 7        8  1115        Chris Jones  03:08:35  2017
# 8        9  1122     Peter Volgyesi  03:09:01  2017
# 9       10  1117  Benjamin Saunders  03:09:13  2017

# %%
full_2017['Time'] = pd.to_timedelta(full_2017['Time'])

# %%
full_2017_topten.describe()
# Out:
#         Overall          Bib                    Time    Year
# count  10.00000    10.000000                      10    10.0
# mean    5.50000  1005.900000  0 days 03:02:44.400000  2017.0
# std     3.02765   354.644251  0 days 00:08:47.078151     0.0
# min     1.00000     1.000000         0 days 02:40:25  2017.0
# 25%     3.25000  1115.500000         0 days 03:01:53  2017.0
# 50%     5.50000  1120.500000  0 days 03:05:36.500000  2017.0
# 75%     7.75000  1133.500000         0 days 03:08:08  2017.0
# max    10.00000  1147.000000         0 days 03:09:13  2017.0

# %%
full_2017_topten['Time'] = pd.to_timedelta(full_2017_topten['Time'])
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
page=0
full_2018 = pd.DataFrame()
for page in range(85):
  base3 = urlbase_2018
  page = page +1
  url3 = base3 + str(page)
  result3 = requests.post(url3)
  soup3 = BS(result3.text, 'lxml')
  tables3 = soup3.find_all("table", attrs = {"class":"table table-responsive table-bordered"})
  results_list3 = pd.read_html(str(tables3[0]))
  full_2018 = full_2018.append(results_list3)

# %%
full_2018['Year'] = 2018

# %%
full_2018['Time'] = pd.to_timedelta(full_2018['Time'])

# %%
full_2018_topten['Time'] = pd.to_timedelta(full_2018_topten['Time'])
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
full_2018_topten = full_2018.head(10)

# %%
full_2018_topten
# Out:
#    Overall    Bib                 Name     Time  Year
# 0        1      1       Scott Wietecha 02:28:16  2018
# 1        2      3         Garang Madut 02:29:52  2018
# 2        3  33442           Kevin Fink 02:38:59  2018
# 3        4  33441        Andrew Hodges 02:43:59  2018
# 4        5  30028      Nicholas Aubert 02:48:11  2018
# 5        6  30038           Dan Shafer 02:49:00  2018
# 6        7  30099         Jacob Rainey 02:51:46  2018
# 7        8  33712            Ry Glover 02:53:17  2018
# 8        9     11  Stella Christoforou 02:53:44  2018
# 9       10  30052     Tyler Hallenbeck 02:56:21  2018

# %%
full_2018_topten.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 5 columns):
# Overall    10 non-null int64
# Bib        10 non-null int64
# Name       10 non-null object
# Time       10 non-null object
# Year       10 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 480.0+ bytes

# %%
full_2018_topten

# %%
full_2018_topten.describe()
# Out:
#         Overall           Bib                    Time    Year
# count  10.00000     10.000000                      10    10.0
# mean    5.50000  22082.700000  0 days 02:45:20.500000  2018.0
# std     3.02765  15310.654461  0 days 00:09:56.897767     0.0
# min     1.00000      1.000000         0 days 02:28:16  2018.0
# 25%     3.25000   7515.250000         0 days 02:40:14  2018.0
# 50%     5.50000  30045.000000  0 days 02:48:35.500000  2018.0
# 75%     7.75000  32605.500000  0 days 02:52:54.250000  2018.0
# max    10.00000  33712.000000         0 days 02:56:21  2018.0

# %%
page=0
full_2019 = pd.DataFrame()
for page in range(113):
  base4 = urlbase_2019
  page = page +1
  url4 = base4 + str(page)
  result4 = requests.post(url4)
  soup4 = BS(result4.text, 'lxml')
  tables4 = soup4.find_all("table", attrs = {"class":"table table-responsive table-bordered"})
  results_list4 = pd.read_html(str(tables4[0]))
  full_2019 = full_2019.append(results_list4)

# %%
full_2019['Year'] = 2019

# %%
full_2019 = full_2019[full_2019['Name'] != "Travis Peruski" ]

# %%
full_2019_topten = full_2019.head(10)

# %%
full_2019_topten
# Out:
#     Overall    Bib               Name     Time  Year
# 1         2      1     Scott Wietecha 02:34:59  2019
# 2         3      4      Jordan Wilson 02:35:24  2019
# 3         4  30034     Steelton Flynn 02:39:59  2019
# 4         5  30035       Thomas Ellis 02:42:09  2019
# 5         6  33172   Nicholas Tseffos 02:48:42  2019
# 6         7  30053  Satoshi Mitsumori 02:50:33  2019
# 7         8  30051   Harrison Kieffer 02:51:18  2019
# 8         9  30086       Steven Forte 02:54:34  2019
# 9        10  30042         Grant Rice 02:55:49  2019
# 10       11  30049      Andrew Fisher 02:56:05  2019

# %%
full_2019['Time'] = pd.to_timedelta(full_2019['Time'])

# %%
full_2019_topten['Time'] = pd.to_timedelta(full_2019_topten['Time'])
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
full_2019_topten.describe()
# Out:
#         Overall           Bib                    Time    Year
# count  10.00000     10.000000                      10    10.0
# mean    6.50000  24352.700000  0 days 02:46:57.200000  2019.0
# std     3.02765  12870.556321  0 days 00:08:11.191250     0.0
# min     2.00000      1.000000         0 days 02:34:59  2019.0
# 25%     4.25000  30034.250000  0 days 02:40:31.500000  2019.0
# 50%     6.50000  30045.500000  0 days 02:49:37.500000  2019.0
# 75%     8.75000  30052.500000         0 days 02:53:45  2019.0
# max    11.00000  33172.000000         0 days 02:56:05  2019.0

# %%
full_2019.head(10)
# Out:
#     Overall    Bib               Name      Time  Year
# 1         2      1     Scott Wietecha  02:34:59  2019
# 2         3      4      Jordan Wilson  02:35:24  2019
# 3         4  30034     Steelton Flynn  02:39:59  2019
# 4         5  30035       Thomas Ellis  02:42:09  2019
# 5         6  33172   Nicholas Tseffos  02:48:42  2019
# 6         7  30053  Satoshi Mitsumori  02:50:33  2019
# 7         8  30051   Harrison Kieffer  02:51:18  2019
# 8         9  30086       Steven Forte  02:54:34  2019
# 9        10  30042         Grant Rice  02:55:49  2019
# 10       11  30049      Andrew Fisher  02:56:05  2019

# %%
all_full_concat = pd.concat([full_2016,full_2017,full_2018,full_2019])

# %%
x = all_full_concat['Year'].value_counts().plot(kind='bar')

# %%
all_full_concat['Time'] = pd.to_timedelta(all_full_concat['Time'])

# %%
all_full_concat.dtypes
# Out:
# Overall              int64
# Bib                  int64
# Name                object
# Time       timedelta64[ns]
# Year                 int64
# dtype: object

# %%
all_full_concat[all_full_concat.Name =='Scott Wietecha']
# Out:
#    Overall  Bib            Name     Time  Year
# 0        1    1  Scott Wietecha 02:25:42  2016
# 0        1    1  Scott Wietecha 02:40:25  2017
# 0        1    1  Scott Wietecha 02:28:16  2018
# 1        2    1  Scott Wietecha 02:34:59  2019

# %%
all_full_concat.shape
# Out:
# (12418, 5)

# %%
full_2018.shape
# Out:
# (2115, 5)

# %%
import matplotlib.pyplot as plt

x = all_full_concat['Year'].value_counts()
x.plot(kind='bar',figsize=(10,5),color='orange')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.title('Number of participants per year')
# Out:
# Text(0.5, 1.0, 'Number of participants per year')

# %%
all_full_concat.Time.describe()
# Out:
# count                     12418
# mean     0 days 03:45:25.576743
# std      0 days 02:05:53.508001
# min             0 days 00:00:00
# 25%             0 days 03:29:21
# 50%             0 days 04:31:57
# 75%             0 days 05:12:03
# max             0 days 07:00:00
# Name: Time, dtype: object

# %%
all_full_concat = all_full_concat[all_full_concat.Time != '00:00:00']

# %%
all_full_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9704 entries, 0 to 24
# Data columns (total 5 columns):
# Overall    9704 non-null int64
# Bib        9704 non-null int64
# Name       9704 non-null object
# Time       9704 non-null timedelta64[ns]
# Year       9704 non-null int64
# dtypes: int64(3), object(1), timedelta64[ns](1)
# memory usage: 454.9+ KB

# %%
all_full_concat.describe(include='all')
# Out:
#              Overall           Bib            Name                    Time  \
# count    9704.000000   9704.000000            9704                    9704
# unique           NaN           NaN            8889                     NaN
# top              NaN           NaN  Richard Brooks                     NaN
# freq             NaN           NaN               5                     NaN
# mean     2801.136954  21932.985367             NaN  0 days 04:48:28.389530
# std     12405.846981  10573.511986             NaN  0 days 00:45:44.662743
# min         1.000000      1.000000             NaN         0 days 01:26:11
# 25%       608.000000  12133.750000             NaN  0 days 04:15:31.500000
# 50%      1214.000000  26058.500000             NaN  0 days 04:49:04.500000
# 75%      1821.000000  31295.000000             NaN         0 days 05:22:04
# max     99999.000000  60042.000000             NaN         0 days 07:00:00
#
#                Year
# count   9704.000000
# unique          NaN
# ...

# %%
all_full_concat.Time

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
all_full_concat['Year'].plot(linewidth=0.5);

cols_plot = ['Seconds', 'Year']
axes = all_full_concat[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Seconds')

# %%
x = all_full_concat['Year'].value_counts().plot(kind='bar')

# %%
# %matplotlib inline

# %%
all_full_concat.describe()
# Out:
#             Overall           Bib                    Time         Year
# count   9704.000000   9704.000000                    9704  9704.000000
# mean    2801.136954  21932.985367  0 days 04:48:28.389530  2017.327391
# std    12405.846981  10573.511986  0 days 00:45:44.662743     1.118593
# min        1.000000      1.000000         0 days 01:26:11  2016.000000
# 25%      608.000000  12133.750000  0 days 04:15:31.500000  2016.000000
# 50%     1214.000000  26058.500000  0 days 04:49:04.500000  2017.000000
# 75%     1821.000000  31295.000000         0 days 05:22:04  2018.000000
# max    99999.000000  60042.000000         0 days 07:00:00  2019.000000

# %%
all_full_concat.Time.tail()
# Out:
# 20   06:29:57
# 21   06:30:17
# 22   06:35:52
# 23   06:36:58
# 24   06:43:55
# Name: Time, dtype: timedelta64[ns]

# %%
all_full_concat.head()
# Out:
#    Overall   Bib               Name     Time  Year
# 0        1     1     Scott Wietecha 02:25:42  2016
# 1        2     3      Brian Shelton 02:34:43  2016
# 2        3  1047  Christopher Capps 02:38:43  2016
# 3        4  1052       Jason Grimes 02:45:06  2016
# 4        5  1046        David Adams 02:47:28  2016

# %%
all_full_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9704 entries, 0 to 24
# Data columns (total 5 columns):
# Overall    9704 non-null int64
# Bib        9704 non-null int64
# Name       9704 non-null object
# Time       9704 non-null timedelta64[ns]
# Year       9704 non-null int64
# dtypes: int64(3), object(1), timedelta64[ns](1)
# memory usage: 454.9+ KB

# %%
print(all_full_concat['Time'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(all_full_concat['Time'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count                      9704
# mean     0 days 04:48:28.389530
# std      0 days 00:45:44.662743
# min             0 days 01:26:11
# 25%      0 days 04:15:31.500000
# 50%      0 days 04:49:04.500000
# 75%             0 days 05:22:04
# max             0 days 07:00:00
# Name: Time, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-ff31e30c3b5e> in <module>
#       1 print(all_full_concat['Time'].describe())
#       2 plt.figure(figsize=(9, 8))
# ----> 3 sns.distplot(all_full_concat['Time'], color='g', bins=100, hist_kws={'alpha': 0.4});
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     223         hist_color = hist_kws.pop("color", color)
# ...

# %%
all_full_concat.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002115F0E9E10>,
# ...
#       dtype=object)

# %%
Time_hist = all_full_concat['Time'].astype('timedelta64[m]').plot.hist()

# %%
grouped = all_full_concat.groupby('Year').count()

# %%
grouped
# Out:
#       Overall   Bib  Name  Time
# Year
# 2016     2978  2978  2978  2978
# 2017     2595  2595  2595  2595
# 2018     2107  2107  2107  2107
# 2019     2024  2024  2024  2024

# %%
ninety_five_quant = grouped.quantile(.95)[0] # [0] since we only need the quantile value
ninety_ninth_quant = grouped.quantile(.99)[0] # [0] since we only need the quantile value
ninety_eight_quant = grouped.quantile(.98)[0] # [0] since we only need the quantile value

# %%
ninety_five_quant
# Out:
# 2920.5499999999997

# %%
ninety_ninth_quant
# Out:
# 2966.51

# %%
ninety_eight_quant
# Out:
# 2955.02

# %%
all_full_concat[all_full_concat.Name =='Scott Wietecha']
# Out:
#    Overall  Bib            Name     Time  Year
# 0        1    1  Scott Wietecha 02:25:42  2016
# 0        1    1  Scott Wietecha 02:40:25  2017
# 0        1    1  Scott Wietecha 02:28:16  2018
# 1        2    1  Scott Wietecha 02:34:59  2019

# %%
Scott_df= all_full_concat[all_full_concat.Name =='Scott Wietecha']

# %%
Scott_df.describe()
# Out:
#        Overall  Bib                    Time         Year
# count     4.00  4.0                       4     4.000000
# mean      1.25  1.0  0 days 02:32:20.500000  2017.500000
# std       0.50  0.0  0 days 00:06:39.351557     1.290994
# min       1.00  1.0         0 days 02:25:42  2016.000000
# 25%       1.00  1.0  0 days 02:27:37.500000  2016.750000
# 50%       1.00  1.0  0 days 02:31:37.500000  2017.500000
# 75%       1.25  1.0  0 days 02:36:20.500000  2018.250000
# max       2.00  1.0         0 days 02:40:25  2019.000000

# %%
Scott_df['Time'] = pd.to_timedelta(Scott_df['Time'])
Scott_df['Seconds'] = Scott_df['Time'].dt.total_seconds()
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Scott_df['Temperature'] = [77,91,73,77]
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Scott_df
# Out:
#    Overall  Bib            Name     Time  Year  Temperature  Seconds
# 0        1    1  Scott Wietecha 02:25:42  2016           77   8742.0
# 0        1    1  Scott Wietecha 02:40:25  2017           91   9625.0
# 0        1    1  Scott Wietecha 02:28:16  2018           73   8896.0
# 1        2    1  Scott Wietecha 02:34:59  2019           77   9299.0

# %%
Scott_df.head()
# Out:
#    Overall  Bib            Name     Time  Year  Temperature  Seconds
# 0        1    1  Scott Wietecha 02:25:42  2016           77   8742.0
# 0        1    1  Scott Wietecha 02:40:25  2017           91   9625.0
# 0        1    1  Scott Wietecha 02:28:16  2018           73   8896.0
# 1        2    1  Scott Wietecha 02:34:59  2019           77   9299.0

# %%
Scott_df['Time'] = pd.to_timedelta(Scott_df['Time'])
Scott_df['Seconds'] = Scott_df['Time'].dt.total_seconds()
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Scott_df.dtypes
# Out:
# Overall                  int64
# Bib                      int64
# Name                    object
# Time           timedelta64[ns]
# Year                     int64
# Temperature              int64
# Seconds                float64
# dtype: object

# %%
Scott_df['Time'] = pd.to_timedelta(Scott_df['Time'])
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
import statsmodels.api as sm

X = Scott_df["Seconds"]
y = Scott_df["Temperature"]
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            Temperature   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.995
# Method:                 Least Squares   F-statistic:                              863.7
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):                    8.65e-05
# Time:                        16:32:12   Log-Likelihood:                         -11.861
# No. Observations:                   4   AIC:                                      25.72
# Df Residuals:                       3   BIC:                                      25.11
# ...

# %%
Scott_df.plot(kind='scatter',x='Temperature',y='Seconds',color='red')
plt.show()

# %%
Scott_selected_col = Scott_df[['Time', 'Year','Temperature']]

# %%
f, x = plt.subplots(figsize=(16, 8))
corr = Scott_df.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
all_full_concat.Time.tail()
# Out:
# 20   06:29:57
# 21   06:30:17
# 22   06:35:52
# 23   06:36:58
# 24   06:43:55
# Name: Time, dtype: timedelta64[ns]

# %%
all_grp = all_full_concat.groupby(['Time'])

# %%
all_full_concat.head(5)
# Out:
#    Overall   Bib               Name     Time  Year
# 0        1     1     Scott Wietecha 02:25:42  2016
# 1        2     3      Brian Shelton 02:34:43  2016
# 2        3  1047  Christopher Capps 02:38:43  2016
# 3        4  1052       Jason Grimes 02:45:06  2016
# 4        5  1046        David Adams 02:47:28  2016

# %%
import statsmodels.api as sm

# %%
all_full_concat.head()
# Out:
#    Overall   Bib               Name     Time  Year
# 0        1     1     Scott Wietecha 02:25:42  2016
# 1        2     3      Brian Shelton 02:34:43  2016
# 2        3  1047  Christopher Capps 02:38:43  2016
# 3        4  1052       Jason Grimes 02:45:06  2016
# 4        5  1046        David Adams 02:47:28  2016

# %%
X = all_full_concat["Seconds"]
y = all_full_concat["Year"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   Year   R-squared (uncentered):                   0.975
# Model:                            OLS   Adj. R-squared (uncentered):              0.975
# Method:                 Least Squares   F-statistic:                          3.858e+05
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):                        0.00
# Time:                        18:06:20   Log-Likelihood:                         -69623.
# No. Observations:                9704   AIC:                                  1.392e+05
# Df Residuals:                    9703   BIC:                                  1.393e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
all_full_concat.dtypes
# Out:
# Overall              int64
# Bib                  int64
# Name                object
# Time       timedelta64[ns]
# Year                 int64
# dtype: object

# %%
all_full_concat['Seconds'] = all_full_concat['Time'].dt.total_seconds()

# %%
all_full_concat.head()
# Out:
#    Overall   Bib               Name     Time  Year  Seconds
# 0        1     1     Scott Wietecha 02:25:42  2016   8742.0
# 1        2     3      Brian Shelton 02:34:43  2016   9283.0
# 2        3  1047  Christopher Capps 02:38:43  2016   9523.0
# 3        4  1052       Jason Grimes 02:45:06  2016   9906.0
# 4        5  1046        David Adams 02:47:28  2016  10048.0

# %%
all_full_concat.to_csv('all_full_concat.csv')

# %%
all_full_concat.tail()
# Out:
#     Overall    Bib               Name     Time  Year  Seconds
# 20     2021  32032    Casey Thomaston 06:29:57  2019  23397.0
# 21     2022  33147   Deanna Alexander 06:30:17  2019  23417.0
# 22     2023  32980      Daniel Albert 06:35:52  2019  23752.0
# 23     2024  30113  Jacqueline Spires 06:36:58  2019  23818.0
# 24     2025  30026        Alex Easley 06:43:55  2019  24235.0

# %%
all_full_concat.plot(kind='scatter',x='Year',y='Seconds',color='red')
plt.show()

# %%
playerBytime = all_full_concat.groupby(['Name','Year'])

# %%
all_full_concat.tail(100)
# Out:
#     Overall    Bib                 Name     Time  Year  Seconds
# 0      1926  32116       Kenneth Missig 05:56:47  2019  21407.0
# 1      1927  31774          Paul Fabian 05:56:59  2019  21419.0
# 2      1928  31088       Andy Lesnefsky 05:56:59  2019  21419.0
# 3      1929  32864        Kellie Tishma 05:57:25  2019  21445.0
# 4      1930  33007      Hector Martinez 05:57:47  2019  21467.0
# 5      1931  32699          Jenn Rogers 05:57:49  2019  21469.0
# 6      1932  33005        Courtney West 05:57:55  2019  21475.0
# 7      1933  31115        Carl Marshall 05:57:57  2019  21477.0
# 8      1934  30587    Christopher Foust 05:58:13  2019  21493.0
# 9      1935  32745        Loretta Green 05:58:16  2019  21496.0
# 10     1936  31865         Tali Kulbeda 05:58:33  2019  21513.0
# 11     1937  32480       Molly Mattocks 05:58:33  2019  21513.0
# 12     1938  32186    Kristina Kaufmann 05:58:37  2019  21517.0
# 13     1939  32418          Ryan Harris 05:58:43  2019  21523.0
# ...

# %%
all_full_concat['Seconds'] = all_full_concat['Time'].dt.total_seconds()

# %%
all_full_concat.head()
# Out:
#    Overall   Bib               Name     Time  Year  Seconds
# 0        1     1     Scott Wietecha 02:25:42  2016   8742.0
# 1        2     3      Brian Shelton 02:34:43  2016   9283.0
# 2        3  1047  Christopher Capps 02:38:43  2016   9523.0
# 3        4  1052       Jason Grimes 02:45:06  2016   9906.0
# 4        5  1046        David Adams 02:47:28  2016  10048.0

# %%
all_full_concat.plot(kind='box',x='Year',y='Seconds',color='red')
plt.show()

# %%
all_full_concat.groupby('Year')['Name'].nunique().plot(kind='bar')
plt.show()

# %%
all_full_concat[all_full_concat.Name =='Christopher Capps']
# Out:
#    Overall   Bib               Name     Time  Year  Seconds
# 2        3  1047  Christopher Capps 02:38:43  2016   9523.0

# %%
top_ten_concat = pd.concat([full_2016_topten,full_2017_topten,full_2018_topten,full_2019_topten])

# %%
top_ten_concat
# Out:
#     Overall    Bib                 Name             Time  Year
# 0         1      1       Scott Wietecha  0 days 02:25:42  2016
# 1         2      3        Brian Shelton  0 days 02:34:43  2016
# 2         3   1047    Christopher Capps  0 days 02:38:43  2016
# 3         4   1052         Jason Grimes  0 days 02:45:06  2016
# 4         5   1046          David Adams  0 days 02:47:28  2016
# 5         6   1049      Matthew Meinema  0 days 02:47:36  2016
# 6         7   1044          Seth Carley  0 days 02:48:22  2016
# 7         8   1092           Ben Becker  0 days 02:52:19  2016
# 8         9   1057       Jonathan Mason  0 days 02:53:38  2016
# 9        10   1058           Matt Treat  0 days 02:53:48  2016
# 0         1      1       Scott Wietecha         02:40:25  2017
# 1         2   1145         Ryan Regnier         02:56:28  2017
# 2         3   1147       Daniel Everett         03:00:55  2017
# 3         4   1029        Khris Vickroy         03:04:47  2017
# ...

# %%
top_ten_concat['Time'] = pd.to_timedelta(top_ten_concat['Time'])
top_ten_concat['Seconds'] = top_ten_concat['Time'].dt.total_seconds()

# %%
top_ten_concat
# Out:
#     Overall    Bib                 Name     Time  Year  Seconds
# 0         1      1       Scott Wietecha 02:25:42  2016   8742.0
# 1         2      3        Brian Shelton 02:34:43  2016   9283.0
# 2         3   1047    Christopher Capps 02:38:43  2016   9523.0
# 3         4   1052         Jason Grimes 02:45:06  2016   9906.0
# 4         5   1046          David Adams 02:47:28  2016  10048.0
# 5         6   1049      Matthew Meinema 02:47:36  2016  10056.0
# 6         7   1044          Seth Carley 02:48:22  2016  10102.0
# 7         8   1092           Ben Becker 02:52:19  2016  10339.0
# 8         9   1057       Jonathan Mason 02:53:38  2016  10418.0
# 9        10   1058           Matt Treat 02:53:48  2016  10428.0
# 0         1      1       Scott Wietecha 02:40:25  2017   9625.0
# 1         2   1145         Ryan Regnier 02:56:28  2017  10588.0
# 2         3   1147       Daniel Everett 03:00:55  2017  10855.0
# 3         4   1029        Khris Vickroy 03:04:47  2017  11087.0
# ...

# %%
all_full_concat['Time'].std()
# Out:
# Timedelta('0 days 00:45:44.662743')

# %%
top_ten_concat.groupby('Year')['Seconds'].nunique().plot(kind='bar')
plt.show()

# %%
list(top_ten_concat['Name'].unique())
# Out:
# ['Scott Wietecha',
#  'Brian Shelton',
#  'Christopher Capps',
#  'Jason Grimes',
#  'David Adams',
#  'Matthew Meinema',
#  'Seth Carley',
#  'Ben Becker',
#  'Jonathan Mason',
#  'Matt Treat',
#  'Ryan Regnier',
#  'Daniel Everett',
#  'Khris Vickroy',
#  'Marcus Dilallo',
#  'Edgar Garza',
#  'Brad Sawa',
#  'Chris Jones',
#  'Peter Volgyesi',
#  'Benjamin Saunders',
#  'Garang Madut',
#  'Kevin Fink',
#  'Andrew Hodges',
#  'Nicholas Aubert',
#  'Dan Shafer',
#  'Jacob Rainey',
#  'Ry Glover',
#  'Stella Christoforou',
#  'Tyler Hallenbeck',
#  'Jordan Wilson',
#  'Steelton Flynn',
#  'Thomas Ellis',
#  'Nicholas Tseffos',
#  'Satoshi Mitsumori',
#  'Harrison Kieffer',
#  'Steven Forte',
#  'Grant Rice',
#  'Andrew Fisher']

# %%
top_ten_concat['Name'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# Name: Name, dtype: bool

# %%
top_ten_concat.describe()
# Out:
#          Overall           Bib                    Time         Year  \
# count  40.000000     40.000000                      40    40.000000
# mean    5.750000  12071.550000  0 days 02:49:56.650000  2017.500000
# std     2.941742  14848.704151  0 days 00:11:29.109069     1.132277
# min     1.000000      1.000000         0 days 02:25:42  2016.000000
# 25%     3.000000   1045.500000         0 days 02:41:43  2016.750000
# 50%     6.000000   1120.500000  0 days 02:50:55.500000  2017.500000
# 75%     8.000000  30043.750000         0 days 02:56:09  2018.250000
# max    11.000000  33712.000000         0 days 03:09:13  2019.000000
#
#            Seconds
# count     40.00000
# mean   10196.65000
# std      689.10907
# min     8742.00000
# 25%     9703.00000
# 50%    10255.50000
# 75%    10569.00000
# max    11353.00000

# %%
top_ten_concat
# Out:
#     Overall    Bib                 Name     Time  Year  Seconds
# 0         1      1       Scott Wietecha 02:25:42  2016   8742.0
# 1         2      3        Brian Shelton 02:34:43  2016   9283.0
# 2         3   1047    Christopher Capps 02:38:43  2016   9523.0
# 3         4   1052         Jason Grimes 02:45:06  2016   9906.0
# 4         5   1046          David Adams 02:47:28  2016  10048.0
# 5         6   1049      Matthew Meinema 02:47:36  2016  10056.0
# 6         7   1044          Seth Carley 02:48:22  2016  10102.0
# 7         8   1092           Ben Becker 02:52:19  2016  10339.0
# 8         9   1057       Jonathan Mason 02:53:38  2016  10418.0
# 9        10   1058           Matt Treat 02:53:48  2016  10428.0
# 0         1      1       Scott Wietecha 02:40:25  2017   9625.0
# 1         2   1145         Ryan Regnier 02:56:28  2017  10588.0
# 2         3   1147       Daniel Everett 03:00:55  2017  10855.0
# 3         4   1029        Khris Vickroy 03:04:47  2017  11087.0
# ...

# %%
num_bins = 'auto'
plt.hist(top_ten_concat['Seconds'], num_bins, normed=1, facecolor='purple', alpha=0.5)
plt.grid(axis='x', alpha=0.75)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Time taken in seconds')
plt.ylabel('Frequency')

plt.show()
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %%
top_ten_concat.sample(5)
# Out:
#    Overall    Bib             Name     Time  Year  Seconds
# 7        8   1092       Ben Becker 02:52:19  2016  10339.0
# 3        4   1029    Khris Vickroy 03:04:47  2017  11087.0
# 4        5  30028  Nicholas Aubert 02:48:11  2018  10091.0
# 6        7  30099     Jacob Rainey 02:51:46  2018  10306.0
# 3        4  30034   Steelton Flynn 02:39:59  2019   9599.0

# %%
top_ten_concat.describe()
# Out:
#          Overall           Bib                    Time         Year  \
# count  40.000000     40.000000                      40    40.000000
# mean    5.750000  12071.550000  0 days 02:49:56.650000  2017.500000
# std     2.941742  14848.704151  0 days 00:11:29.109069     1.132277
# min     1.000000      1.000000         0 days 02:25:42  2016.000000
# 25%     3.000000   1045.500000         0 days 02:41:43  2016.750000
# 50%     6.000000   1120.500000  0 days 02:50:55.500000  2017.500000
# 75%     8.000000  30043.750000         0 days 02:56:09  2018.250000
# max    11.000000  33712.000000         0 days 03:09:13  2019.000000
#
#            Seconds
# count     40.00000
# mean   10196.65000
# std      689.10907
# min     8742.00000
# 25%     9703.00000
# 50%    10255.50000
# 75%    10569.00000
# max    11353.00000

# %%
top_ten_concat['Seconds'].median()
# Out:
# 10255.5

# %%
q=0.5
top_ten_concat['Seconds'].quantile(q)
# Out:
# 10255.5

# %%
import seaborn as sns

sns.set_style('darkgrid')
sns.distplot((all_full_concat['Seconds']))

# %%
sns.scatterplot(x='Year',y='Seconds',data=all_full_concat)

# %%
sns_all_full = sns.catplot(x="Year", y="Seconds", kind="swarm", data=all_full_concat)

plt.savefig('sns_all_full.png')

# %%
top_ten_concat
# Out:
#     Overall    Bib                 Name     Time  Year  Seconds
# 0         1      1       Scott Wietecha 02:25:42  2016   8742.0
# 1         2      3        Brian Shelton 02:34:43  2016   9283.0
# 2         3   1047    Christopher Capps 02:38:43  2016   9523.0
# 3         4   1052         Jason Grimes 02:45:06  2016   9906.0
# 4         5   1046          David Adams 02:47:28  2016  10048.0
# 5         6   1049      Matthew Meinema 02:47:36  2016  10056.0
# 6         7   1044          Seth Carley 02:48:22  2016  10102.0
# 7         8   1092           Ben Becker 02:52:19  2016  10339.0
# 8         9   1057       Jonathan Mason 02:53:38  2016  10418.0
# 9        10   1058           Matt Treat 02:53:48  2016  10428.0
# 0         1      1       Scott Wietecha 02:40:25  2017   9625.0
# 1         2   1145         Ryan Regnier 02:56:28  2017  10588.0
# 2         3   1147       Daniel Everett 03:00:55  2017  10855.0
# 3         4   1029        Khris Vickroy 03:04:47  2017  11087.0
# ...

# %%
sns.countplot(all_full_concat['Year'])
plt.savefig('participation.png')

# %%
plt.savefig('participation.png')

# %%
X = Scott_df["Temperature"]
y = Scott_df["Seconds"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                Seconds   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.995
# Method:                 Least Squares   F-statistic:                              863.7
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):                    8.65e-05
# Time:                        20:41:05   Log-Likelihood:                         -30.828
# No. Observations:                   4   AIC:                                      63.66
# Df Residuals:                       3   BIC:                                      63.04
# ...

# %%
#Time will increase/decrease  114.4354 seconds with temperature increase/decrease 1 degree ferenhite
#confidence level is 97.5% and time will increase/decrease 126.827 seconds with every unit of temperature changes.

# %%
Scott_df
# Out:
#    Overall  Bib            Name     Time  Year  Temperature  Seconds
# 0        1    1  Scott Wietecha 02:25:42  2016           77   8742.0
# 0        1    1  Scott Wietecha 02:40:25  2017           91   9625.0
# 0        1    1  Scott Wietecha 02:28:16  2018           73   8896.0
# 1        2    1  Scott Wietecha 02:34:59  2019           77   9299.0

# %%
Scott_df['Temperature'].plot(linewidth=0.5);

cols_plot = ['Seconds', 'Year']
axes = all_full_concat[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Temperature')

# %%
top_ten_concat.shape
# Out:
# (40, 6)

# %%
top_ten_concat
# Out:
#     Overall    Bib                 Name     Time  Year  Seconds
# 0         1      1       Scott Wietecha 02:25:42  2016   8742.0
# 1         2      3        Brian Shelton 02:34:43  2016   9283.0
# 2         3   1047    Christopher Capps 02:38:43  2016   9523.0
# 3         4   1052         Jason Grimes 02:45:06  2016   9906.0
# 4         5   1046          David Adams 02:47:28  2016  10048.0
# 5         6   1049      Matthew Meinema 02:47:36  2016  10056.0
# 6         7   1044          Seth Carley 02:48:22  2016  10102.0
# 7         8   1092           Ben Becker 02:52:19  2016  10339.0
# 8         9   1057       Jonathan Mason 02:53:38  2016  10418.0
# 9        10   1058           Matt Treat 02:53:48  2016  10428.0
# 0         1      1       Scott Wietecha 02:40:25  2017   9625.0
# 1         2   1145         Ryan Regnier 02:56:28  2017  10588.0
# 2         3   1147       Daniel Everett 03:00:55  2017  10855.0
# 3         4   1029        Khris Vickroy 03:04:47  2017  11087.0
# ...

# %%
Corr_temp = ('Average time taken', 'Temperature')

# %%
Corr_temp ['Temperature'] = [77,91,73,77]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-192-f3eeb5c2b052> in <module>
# ----> 1 Corr_temp ['Temperature'] = [77,91,73,77]
#
# TypeError: 'tuple' object does not support item assignment

# %%
Corr_temp.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-228-dfa4f585352d> in <module>
# ----> 1 Corr_temp.info()
#
# AttributeError: 'tuple' object has no attribute 'info'

# %%
Corr_weather = pd.read_csv('corr_temp.csv')

# %%
Corr_weather
# Out:
#   Avg_time  Temp  Wind speed   Humidity
# 0  2:44:44    77            3        87
# 1  3:02:44    91           14        74
# 2  2:45:20    70           10        39
# 3  2:46:57    77           10        30

# %%
Corr_weather['Avg_time'] = pd.to_timedelta(Corr_weather['Avg_time'])
Corr_weather['Seconds'] = Corr_weather['Avg_time'].dt.total_seconds()

# %%
Corr_weather
# Out:
#   Avg_time  Temp  Wind speed   Humidity  Seconds
# 0 02:44:44    77            3        87   9884.0
# 1 03:02:44    91           14        74  10964.0
# 2 02:45:20    70           10        39   9920.0
# 3 02:46:57    77           10        30  10017.0

# %%
Corr_weather.corr()
# Out:
#                  Temp  Wind speed   Humidity   Seconds
# Temp         1.000000     0.506821  0.499160  0.932101
# Wind speed   0.506821     1.000000 -0.374670  0.744084
# Humidity     0.499160    -0.374670  1.000000  0.319677
# Seconds      0.932101     0.744084  0.319677  1.000000

# %%
f, x = plt.subplots(figsize=(16, 8))
corr = Corr_weather.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
Corr_weather.describe()
# Out:
#                      Avg_time      Temp  Wind speed    Humidity       Seconds
# count                       4   4.00000     4.000000   4.000000      4.000000
# mean   0 days 02:49:56.250000  78.75000     9.250000  57.500000  10196.250000
# std    0 days 00:08:34.906059   8.80814     4.573474  27.331301    514.906059
# min           0 days 02:44:44  70.00000     3.000000  30.000000   9884.000000
# 25%           0 days 02:45:11  75.25000     8.250000  36.750000   9911.000000
# 50%    0 days 02:46:08.500000  77.00000    10.000000  56.500000   9968.500000
# 75%    0 days 02:50:53.750000  80.50000    11.000000  77.250000  10253.750000
# max           0 days 03:02:44  91.00000    14.000000  87.000000  10964.000000

# %%
X = Corr_weather["Temp"]
y = Corr_weather["Seconds"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                Seconds   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.996
# Method:                 Least Squares   F-statistic:                              889.2
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):                    8.28e-05
# Time:                        19:06:06   Log-Likelihood:                         -31.209
# No. Observations:                   4   AIC:                                      64.42
# Df Residuals:                       3   BIC:                                      63.80
# ...

# %%
full_2016_topten.difference(full_2017_topten)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-200-aa40c14c1a51> in <module>
# ----> 1 full_2016_topten.difference(full_2017_topten)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'difference'

# %%
x1= full_2016_topten

# %%
y1 = full_2017_topten

# %%
full_2017_topten
# Out:
#    Overall   Bib               Name     Time  Year
# 0        1     1     Scott Wietecha 02:40:25  2017
# 1        2  1145       Ryan Regnier 02:56:28  2017
# 2        3  1147     Daniel Everett 03:00:55  2017
# 3        4  1029      Khris Vickroy 03:04:47  2017
# 4        5  1119     Marcus Dilallo 03:04:53  2017
# 5        6  1135        Edgar Garza 03:06:20  2017
# 6        7  1129          Brad Sawa 03:06:47  2017
# 7        8  1115        Chris Jones 03:08:35  2017
# 8        9  1122     Peter Volgyesi 03:09:01  2017
# 9       10  1117  Benjamin Saunders 03:09:13  2017

# %%
full_2017_topten['Time'] = pd.to_timedelta(full_2017_topten['Time'])
full_2017_topten['Seconds'] = full_2017_topten['Time'].dt.total_seconds()
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
full_2017_topten
# Out:
#    Overall   Bib               Name     Time  Year  Seconds
# 0        1     1     Scott Wietecha 02:40:25  2017   9625.0
# 1        2  1145       Ryan Regnier 02:56:28  2017  10588.0
# 2        3  1147     Daniel Everett 03:00:55  2017  10855.0
# 3        4  1029      Khris Vickroy 03:04:47  2017  11087.0
# 4        5  1119     Marcus Dilallo 03:04:53  2017  11093.0
# 5        6  1135        Edgar Garza 03:06:20  2017  11180.0
# 6        7  1129          Brad Sawa 03:06:47  2017  11207.0
# 7        8  1115        Chris Jones 03:08:35  2017  11315.0
# 8        9  1122     Peter Volgyesi 03:09:01  2017  11341.0
# 9       10  1117  Benjamin Saunders 03:09:13  2017  11353.0

# %%
full_2017_topten.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 6 columns):
# Overall    10 non-null int64
# Bib        10 non-null int64
# Name       10 non-null object
# Time       10 non-null timedelta64[ns]
# Year       10 non-null int64
# Seconds    10 non-null float64
# dtypes: float64(1), int64(3), object(1), timedelta64[ns](1)
# memory usage: 560.0+ bytes

# %%
Scott_humid = pd.read_csv('Scott_humid.csv')

# %%
Scott_humid
# Out:
#   Time_diff  In Seconds  Humidity
# 0   0:09:01         541        87
# 1   0:16:03         963        74
# 2   0:01:06          96        39
# 3   0:00:25          25        30

# %%
Scott_humid.corr()
# Out:
#             In Seconds  Humidity
# In Seconds    1.000000  0.822386
# Humidity      0.822386  1.000000

# %%
X = Scott_humid["Humidity"]
y = Scott_humid["In Seconds"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             In Seconds   R-squared (uncentered):                   0.793
# Model:                            OLS   Adj. R-squared (uncentered):              0.724
# Method:                 Least Squares   F-statistic:                              11.50
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):                      0.0427
# Time:                        19:53:46   Log-Likelihood:                         -27.797
# No. Observations:                   4   AIC:                                      57.59
# Df Residuals:                       3   BIC:                                      56.98
# ...

# %%
all_full_concat.describe()
# Out:
#             Overall           Bib                    Time         Year  \
# count   9704.000000   9704.000000                    9704  9704.000000
# mean    2801.136954  21932.985367  0 days 04:48:28.389530  2017.327391
# std    12405.846981  10573.511986  0 days 00:45:44.662743     1.118593
# min        1.000000      1.000000         0 days 01:26:11  2016.000000
# 25%      608.000000  12133.750000  0 days 04:15:31.500000  2016.000000
# 50%     1214.000000  26058.500000  0 days 04:49:04.500000  2017.000000
# 75%     1821.000000  31295.000000         0 days 05:22:04  2018.000000
# max    99999.000000  60042.000000         0 days 07:00:00  2019.000000
#
#             Seconds
# count   9704.000000
# mean   17308.389530
# std     2744.662743
# min     5171.000000
# 25%    15331.500000
# 50%    17344.500000
# 75%    19324.000000
# max    25200.000000

# %%
full_2018.describe()
# Out:
#             Overall           Bib                    Time    Year
# count   2810.000000   2810.000000                    2810  2810.0
# mean   28701.259075  31362.693238  0 days 03:23:14.292882  2019.0
# std    44441.235585   3029.438948  0 days 02:12:22.677846     0.0
# min        2.000000      1.000000         0 days 00:00:00  2019.0
# 25%      704.250000  30784.250000         0 days 00:00:00  2019.0
# 50%     1406.500000  31587.500000         0 days 04:17:11  2019.0
# 75%    99999.000000  32399.500000         0 days 04:59:57  2019.0
# max    99999.000000  50463.000000         0 days 06:43:55  2019.0

# %%
sns.lmplot(x='Humidity', y='In Seconds', data=Scott_humid)

# %%
Scott_humid.cov()
# Out:
#                In Seconds     Humidity
# In Seconds  189911.583333  9795.166667
# Humidity      9795.166667   747.000000
